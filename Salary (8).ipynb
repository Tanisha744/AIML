# %%
import pandas as pd

data=pd.read_csv("Salaries.csv")
dataframe = pd.DataFrame(data)
data
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_13528\1819037211.py:3: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("Salaries.csv")
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %% [markdown]
# # Display TOP 10 ROWS OF THE DATASET

# %%
dataframe.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %% [markdown]
# # CHECK LAST 10 ROWS OF THE DATASET

# %%
dataframe.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# # FIND SHAPE OF OUR DATASET(NUMBER OF ROWS AND NUMBER OF COLUMNS)

# %%
dataframe.dtypes
# Out:
# Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay              object
# OvertimePay          object
# OtherPay             object
# Benefits             object
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status               object
# dtype: object

# %% [markdown]
# # GETTING INFORMATION ABOUT OUR DATASET LIKE TOTAL NUMBER ROWS,TOTAL NUMBER OF COLUMNS,DATATYPES OF EACH COLUMN AND MEMORY REQUIREMENT

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %% [markdown]
# # CHECK NULL VALUES IN THE DATASET

# %%
dataframe.isnull()
# Out:
#            Id  EmployeeName  JobTitle  BasePay  OvertimePay  OtherPay  \
# 0       False         False     False    False        False     False
# 1       False         False     False    False        False     False
# 2       False         False     False    False        False     False
# 3       False         False     False    False        False     False
# 4       False         False     False    False        False     False
# ...       ...           ...       ...      ...          ...       ...
# 148649  False         False     False    False        False     False
# 148650  False         False     False    False        False     False
# 148651  False         False     False    False        False     False
# 148652  False         False     False    False        False     False
# 148653  False         False     False    False        False     False
#
#         Benefits  TotalPay  TotalPayBenefits   Year  Notes  Agency  Status
# ...

# %% [markdown]
# # DROP ID,NOTES,AGENCY AND STATUS COLUMNS

# %%
dataframe.drop(["Id","Notes","Agency","Status"],axis=1)
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# # FIND OCCURRENCE OF THE EMPLOYEE NAME(TOP5)

# %%
dataframe["EmployeeName"].value_counts().head(5)
# Out:
# Kevin Lee       13
# Richard Lee     11
# Steven Lee      11
# William Wong    11
# Stanley Lee      9
# Name: EmployeeName, dtype: int64

# %% [markdown]
# # FIND THE NUMBER OF UNIQUE JOB TITLES

# %%
dataframe["JobTitle"].nunique()
# Out:
# 2159

# %% [markdown]
# # TOTAL NUMBER OF JOBS TITLES CONTAINS CAPTAIN

# %%
dataframe["JobTitle"].str.contains("CAPTAIN").sum()
# Out:
# 141

# %% [markdown]
# # DISPLAY ALL THE EMPLOYEE NAMES FROM FIRE DEPARTMENT

# %%
dataframe[dataframe["JobTitle"].str.contains("FIRE")].get(["EmployeeName"])
# Out:
#              EmployeeName
# 4         PATRICK GARDNER
# 6               ALSON LEE
# 8          MICHAEL MORRIS
# 9      JOANNE HAYES-WHITE
# 10          ARTHUR KENNEY
# ...                   ...
# 34790     CHARLES JOHNSON
# 34927       THOMAS LEEPER
# 35811       ROBERTO LUCHA
# 36076         DEBRA TANIS
# 36153       ROCK CRAWFORD
#
# [1459 rows x 1 columns]

# %%
# to fix BasePay object error
dataframe['BasePay'] = pd.to_numeric(dataframe['BasePay'],errors="coerce")

# %% [markdown]
# # FIND MINIMUM,MAXIMUM AND AVERGE BASEPAY

# %%
print("min basepay :",dataframe["BasePay"].min())
print("max basepay :",dataframe["BasePay"].max())
print("avg basepay :",dataframe["BasePay"].mean())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13528\4057634122.py in <module>
# ----> 1 print("min basepay :",dataframe["BasePay"].min())
#       2 print("max basepay :",dataframe["BasePay"].max())
#       3 print("avg basepay :",dataframe["BasePay"].mean())
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in min(self, axis, skipna, level, numeric_only, **kwargs)
#   11242             **kwargs,
#   11243         ):
# > 11244             return NDFrame.min(self, axis, skipna, level, numeric_only, **kwargs)
#   11245
#   11246         setattr(cls, "min", min)
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in min(self, axis, skipna, level, numeric_only, **kwargs)
#   10656         **kwargs,
#   10657     ):
# > 10658         return self._stat_function(
#   10659             "min",
#   10660             nanops.nanmin,
#
# ...

# %% [markdown]
# # REPLACE 'NOT PROVIDED' IN  EMPLOYEENAME COLUMN TO NaN

# %%
dataframe.replace("Not Provided","NaN")
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay OvertimePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.0
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02   245131.88
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13   106088.18
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC    77916.0    56120.71
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)   134401.6      9737.0
# ...                                                ...        ...         ...
# ...

# %% [markdown]
# # drop the rows having more than 5 missing values

# %%
dataframe.dropna(thresh=5)
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# # find the job title of ALBERT PARDINI

# %%
dataframe[dataframe["EmployeeName"].str.contains("ALBERT PARDINI")].get(["JobTitle"])
# Out:
#                           JobTitle
# 2  CAPTAIN III (POLICE DEPARTMENT)

# %% [markdown]
# # HOW MUCH ALBERT PARDINI MAKE (INCULDE DENEFITS)?

# %%
dataframe[dataframe["EmployeeName"].str.contains("ALBERT PARDINI")].get(["TotalPay"])
# Out:
#     TotalPay
# 2  335279.91

# %% [markdown]
# # DISPLAY NAME OF THE PERSON HAVINNG THE HIGHEST BASEPAY

# %%
dataframe[dataframe["BasePay"]==dataframe["BasePay"].max()].get(["EmployeeName"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13528\3499910052.py in <module>
# ----> 1 dataframe[dataframe["BasePay"]==dataframe["BasePay"].max()].get(["EmployeeName"])
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   11217             **kwargs,
#   11218         ):
# > 11219             return NDFrame.max(self, axis, skipna, level, numeric_only, **kwargs)
#   11220
#   11221         setattr(cls, "max", max)
#
# C:\Anaconda\lib\site-packages\pandas\core\generic.py in max(self, axis, skipna, level, numeric_only, **kwargs)
#   10674         **kwargs,
#   10675     ):
# > 10676         return self._stat_function(
#   10677             "max",
#   10678             nanops.nanmax,
#
# ...

# %% [markdown]
# # FIND AVERGE BASEPAY OF ALL EMPLOYEE PER YEAR

# %%
dataframe.groupby('Year')['BasePay'].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in array_func(values)
#    1586             try:
# -> 1587                 result = self.grouper._cython_operation(
#    1588                     "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#
# C:\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     938         ngroups = self.ngroups
# --> 939         return cy_op.cython_operation(
#     940             values=values,
#
# C:\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     625
# --> 626         return self._cython_op_ndim_compat(
#     627             values,
#
# ...

# %% [markdown]
# # FIND AVERGE BASEPAY OF ALL EMPLOYEE PER JOB TITLE

# %%
dataframe.groupby('JobTitle')['BasePay'].mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# C:\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in array_func(values)
#    1586             try:
# -> 1587                 result = self.grouper._cython_operation(
#    1588                     "aggregate", values, how, axis=data.ndim - 1, min_count=min_count
#
# C:\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     938         ngroups = self.ngroups
# --> 939         return cy_op.cython_operation(
#     940             values=values,
#
# C:\Anaconda\lib\site-packages\pandas\core\groupby\ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     625
# --> 626         return self._cython_op_ndim_compat(
#     627             values,
#
# ...

# %% [markdown]
# # FIND AVERGE BASEPAY OF EMPLOYEE HAVIG JOB TITLE ACCOUNTANT

# %%
dataframe[dataframe["JobTitle"].str.contains("ACCOUNTANT")].get(["BasePay"]).mean()

# %% [markdown]
# # FIND TOP5 MOST COMMAN JOBS

# %%
dataframe["JobTitle"].value_counts().head(5)
